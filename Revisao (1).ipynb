# %%
# No terminal, uma vez: python -m pip install openpyxl pandas xlrd matplotlib seaborn
import pandas as pd
import openpyxl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid", palette="Set2")

# %%
# Caminho do arquivo Excel (coloque o .xlsx na mesma pasta do notebook)
path = r"Tabela_11_Domicilios_sem_presenca_de_conjuge_e_com_filhos.xlsx"

# %% [markdown]
# # Sexo da pessoa responsável pelo domicílio

# %%
#Lé todas as abas do arquivo
todas = pd.read_excel(path, sheet_name=None, header=None)
print(todas.keys())
# Out:
# dict_keys(['BR GR UF MU', 'Tabela base do SIDRA 9882'])

# %%
bruto = pd.read_excel(path, sheet_name="Tabela base do SIDRA 9882", header=None)

# %%
bruto
# Out:
#                                                       0  \
# 0     Tabela 9882 - Domicílios particulares, por pre...
# 1       Variável - Domicílios particulares (Domicílios)
# 2                                            Ano - 2022
# 3     Brasil, Grande Região, Unidade da Federação e ...
# 4                                                   NaN
# ...                                                 ...
# 5604                                Vicentinópolis (GO)
# 5605                                      Vila Boa (GO)
# 5606                                 Vila Propício (GO)
# 5607                                      Brasília (DF)
# 5608                    Fonte: IBGE - Censo Demográfico
#
#                                               1       2         3
# 0                                           NaN     NaN       NaN
# 1                                           NaN     NaN       NaN
# 2                                           NaN     NaN       NaN
# 3     Sexo da pessoa responsável pelo domicílio     NaN       NaN
# 4                                         Total  Homens  Mulheres
# ...                                         ...     ...       ...
# 5604                                        352      55       297
# 5605                                        226      37       189
# 5606                                        267      49       218
# 5607                                     184921   24110    160811
# 5608                                        NaN     NaN       NaN
#
# [5609 rows x 4 columns]

# %%
indicador_2 = bruto.iloc[5:5608].copy()

# %%
indicador_2
# Out:
#                         0         1        2         3
# 5                  Brasil  11936510  1614739  10321771
# 6                   Norte    909212   149246    759966
# 7                Nordeste   3487048   411968   3075080
# 8                 Sudeste   5105674   700511   4405163
# 9                     Sul   1537469   228801   1308668
# ...                   ...       ...      ...       ...
# 5603      Vianópolis (GO)       689       87       602
# 5604  Vicentinópolis (GO)       352       55       297
# 5605        Vila Boa (GO)       226       37       189
# 5606   Vila Propício (GO)       267       49       218
# 5607        Brasília (DF)    184921    24110    160811
#
# [5603 rows x 4 columns]

# %%
# Preenchendo os nomes das colunas
indicador_2.columns = [
    "regiao",
    "total",
    "homens",
    "mulheres",
]

# %%
indicador_2 = indicador_2.reset_index(drop=True)

# horas são número, não texto
for col in indicador_2.columns[1:]:
    indicador_2[col] = pd.to_numeric(indicador_2[col], errors="coerce")

indicador_2
# Out:
#                    regiao     total   homens  mulheres
# 0                  Brasil  11936510  1614739  10321771
# 1                   Norte    909212   149246    759966
# 2                Nordeste   3487048   411968   3075080
# 3                 Sudeste   5105674   700511   4405163
# 4                     Sul   1537469   228801   1308668
# ...                   ...       ...      ...       ...
# 5598      Vianópolis (GO)       689       87       602
# 5599  Vicentinópolis (GO)       352       55       297
# 5600        Vila Boa (GO)       226       37       189
# 5601   Vila Propício (GO)       267       49       218
# 5602        Brasília (DF)    184921    24110    160811
#
# [5603 rows x 4 columns]

# %%
indicador_2.describe()
# Out:
#               total        homens      mulheres
# count  5.603000e+03  5.603000e+03  5.603000e+03
# mean   8.521513e+03  1.152767e+03  7.368746e+03
# std    1.879794e+05  2.535391e+04  1.626494e+05
# min    2.300000e+01  3.000000e+00  1.600000e+01
# 25%    2.500000e+02  4.000000e+01  2.090000e+02
# 50%    5.660000e+02  8.700000e+01  4.730000e+02
# 75%    1.323500e+03  1.890000e+02  1.134000e+03
# max    1.193651e+07  1.614739e+06  1.032177e+07

# %%
indicador_2.describe().round(2)
# Out:
#              total      homens     mulheres
# count      5603.00     5603.00      5603.00
# mean       8521.51     1152.77      7368.75
# std      187979.37    25353.91    162649.37
# min          23.00        3.00        16.00
# 25%         250.00       40.00       209.00
# 50%         566.00       87.00       473.00
# 75%        1323.50      189.00      1134.00
# max    11936510.00  1614739.00  10321771.00

# %% [markdown]
# EXCLUIR AS CIDADES, REPAREM NO PADRÃO, ELAS TEM O () QUE INDICAM O UF

# %%
# ~ nega a condição: fica só quem NÃO tem "(" no nome (ou seja, tira as cidades)
indicador_2 = indicador_2[~indicador_2["regiao"].str.contains(r"\(", na=False)]
indicador_2
# Out:
#                  regiao     total   homens  mulheres
# 0                Brasil  11936510  1614739  10321771
# 1                 Norte    909212   149246    759966
# 2              Nordeste   3487048   411968   3075080
# 3               Sudeste   5105674   700511   4405163
# 4                   Sul   1537469   228801   1308668
# 5          Centro-Oeste    897107   124213    772894
# 6              Rondônia     78597    12520     66077
# 7                  Acre     47506     7166     40340
# 8              Amazonas    205036    37693    167343
# 9               Roraima     31690     5072     26618
# 10                 Pará    423309    67853    355456
# 11                Amapá     42958     7288     35670
# 12            Tocantins     80116    11654     68462
# 13             Maranhão    384488    50219    334269
# 14                Piauí    192425    23505    168920
# 15                Ceará    558869    64440    494429
# 16  Rio Grande do Norte    204565    24132    180433
# 17              Paraíba    240849    27585    213264
# 18           Pernambuco    598783    64573    534210
# 19              Alagoas    192706    21961    170745
# 20              Sergipe    155980    16312    139668
# 21                Bahia    958383   119241    839142
# 22         Minas Gerais   1258188   171679   1086509
# 23       Espírito Santo    214564    30152    184412
# 24       Rio de Janeiro   1067294   146596    920698
# 25            São Paulo   2565628   352084   2213544
# 26               Paraná    593410    85773    507637
# 27       Santa Catarina    340157    53269    286888
# 28    Rio Grande do Sul    603902    89759    514143
# 29   Mato Grosso do Sul    150374    21034    129340
# 30          Mato Grosso    172804    26431    146373
# 31                Goiás    389008    52638    336370
# 32     Distrito Federal    184921    24110    160811

# %% [markdown]
# # Trazer a Tabela 1.1.1 (horas de trabalho doméstico) e juntar com indicador_2

# %%
# Mesma limpeza da Aula 2: linhas 8–40, nomes de coluna, horas como número
# TROQUE pelo caminho real do arquivo .xls da Tabela 1.1.1 (o mesmo usado na Aula 2)
path_horas = r"PATH TABELA AULA 2"
bruto_1 = pd.read_excel(path_horas, engine="xlrd", header=None)

indicador_1 = bruto_1.iloc[8:41].copy()
indicador_1.columns = [
    "uf_regiao",
    "total",
    "total_branca",
    "total_preta_parda",
    "homem_branca",
    "homem_preta_parda",
    "mulher_branca",
    "mulher_preta_parda",
]
indicador_1 = indicador_1.reset_index(drop=True)
for col in indicador_1.columns[1:]:
    indicador_1[col] = pd.to_numeric(indicador_1[col], errors="coerce")

indicador_1
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 4
#       1 # Mesma limpeza da Aula 2: linhas 8–40, nomes de coluna, horas como número
#       2 # TROQUE pelo caminho real do arquivo .xls da Tabela 1.1.1 (o mesmo usado na Aula 2)
#       3 path_horas = r"PATH TABELA AULA 2"
# ----> 4 bruto_1 = pd.read_excel(path_horas, engine="xlrd", header=None)
#       5
#       6 indicador_1 = bruto_1.iloc[8:41].copy()
#       7 indicador_1.columns = [
#
# File /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py:481, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     479 if not isinstance(io, ExcelFile):
#     480     should_close = True
# --> 481     io = ExcelFile(
#     482         io,
#     483         storage_options=storage_options,
#     484         engine=engine,
#     485         engine_kwargs=engine_kwargs,
#     486     )
#     487 elif engine and engine != io.engine:
#     488     raise ValueError(
#     489         "Engine should not be specified when passing "
#     490         "an ExcelFile - ExcelFile already has the engine set"
#     491     )
#
# File /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py:1621, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1618 self.engine = engine
#    1619 self.storage_options = storage_options
# -> 1621 self._reader = self._engines[engine](
#    1622     self._io,
#    1623     storage_options=storage_options,
#    1624     engine_kwargs=engine_kwargs,
#    1625 )
#
# File /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_xlrd.py:51, in XlrdReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#      49 err_msg = "Install xlrd >= 2.0.1 for xls Excel support"
#      50 import_optional_dependency("xlrd", extra=err_msg)
# ---> 51 super().__init__(
#      52     filepath_or_buffer,
#      53     storage_options=storage_options,
#      54     engine_kwargs=engine_kwargs,
#      55 )
#
# File /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py:544, in BaseExcelReader.__init__(self, filepath_or_buffer, storage_options, engine_kwargs)
#     540 self.handles = IOHandles(
#     541     handle=filepath_or_buffer, compression={"method": None}
#     542 )
#     543 if not isinstance(filepath_or_buffer, (ExcelFile, self._workbook_class)):
# --> 544     self.handles = get_handle(
#     545         filepath_or_buffer, "rb", storage_options=storage_options, is_text=False
#     546     )
#     548 if isinstance(self.handles.handle, self._workbook_class):
#     549     self.book = self.handles.handle
#
# File /usr/local/lib/python3.12/dist-packages/pandas/io/common.py:935, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#    (...)    931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
# --> 935         handle = open(handle, ioargs.mode)
#     936     handles.append(handle)
#     938 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'PATH TABELA AULA 2'

# %%
# Left join: fica tudo de indicador_2; puxa as horas da 1.1.1 quando o nome bate
# suffixes: as duas tabelas têm coluna "total" — domicílios vs horas
indicador1e2 = indicador_2.merge(
    indicador_1,
    how="left",
    left_on="regiao",
    right_on="uf_regiao",
    suffixes=("_domicilios", "_horas"),
)
indicador1e2 = indicador1e2.drop(columns=["uf_regiao"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       1 # Left join: fica tudo de indicador_2; puxa as horas da 1.1.1 quando o nome bate
#       2 # suffixes: as duas tabelas têm coluna "total" — domicílios vs horas
#       3 indicador1e2 = indicador_2.merge(
# ----> 4     indicador_1,
#       5     how="left",
#       6     left_on="regiao",
#       7     right_on="uf_regiao",
#
# NameError: name 'indicador_1' is not defined

# %%
indicador1e2 = indicador1e2.rename(columns={
    "homens": "resp_domicilio_homens",
    "mulheres": "resp_domicilio_mulheres",
})
indicador1e2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 indicador1e2 = indicador1e2.rename(columns={
#       2     "homens": "resp_domicilio_homens",
#       3     "mulheres": "resp_domicilio_mulheres",
#       4 })
#
# NameError: name 'indicador1e2' is not defined

# %%
# % de domicílios com responsável mulher  |  horas médias das mulheres (média das duas raças)
indicador1e2["pct_resp_mulheres"] = (
    indicador1e2["resp_domicilio_mulheres"] / indicador1e2["total_domicilios"] * 100
)
indicador1e2["horas_mulher"] = (
    indicador1e2["mulher_branca"] + indicador1e2["mulher_preta_parda"]
) / 2

indicador1e2[
    ["regiao", "pct_resp_mulheres", "horas_mulher", "resp_domicilio_mulheres", "total_domicilios"]
].sort_values("pct_resp_mulheres", ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 # % de domicílios com responsável mulher  |  horas médias das mulheres (média das duas raças)
#       2 indicador1e2["pct_resp_mulheres"] = (
# ----> 3     indicador1e2["resp_domicilio_mulheres"] / indicador1e2["total_domicilios"] * 100
#       4 )
#       5 indicador1e2["horas_mulher"] = (
#       6     indicador1e2["mulher_branca"] + indicador1e2["mulher_preta_parda"]
#
# NameError: name 'indicador1e2' is not defined

# %% [markdown]
# pct_resp_mulheres = em cada 100 desses domicílios, quantos têm mulher responsável.
# horas_mulher = média semanal de horas das mulheres (média simples de branca e preta/parda na 1.1.1).
# Como ler os dois juntos. Nordeste concentra os dois: Sergipe ~90% de responsáveis mulheres e ~24 h; Alagoas ~89% e ~25 h (mais horas). Norte tem menos lares com responsável mulher (Amazonas ~82%) e menos horas (Amapá, Acre, Roraima ~16 h). DF é o contraste: muitas responsáveis mulheres (~87%) e menos horas (~18,5 h).

# %%
# Neste recorte (sem cônjuge + com filhos): mulheres são maioria?
indicador_2["mais_mulheres"] = indicador_2["mulheres"] > indicador_2["homens"]

brasil = indicador_2.loc[indicador_2["regiao"] == "Brasil"].iloc[0]
print("Brasil — domicílios sem cônjuge e com filhos (Censo 2022)")
print(f"  mulheres: {int(brasil.mulheres):,}  ({brasil.mulheres/brasil.total*100:.1f}%)")
print(f"  homens:   {int(brasil.homens):,}  ({brasil.homens/brasil.total*100:.1f}%)")
print(f"  {brasil.mulheres/brasil.homens:.1f} mulheres para cada homem responsável")
print()
print("Em todas as UFs/regiões mulheres > homens?", indicador_2["mais_mulheres"].all())

indicador_2[["regiao", "homens", "mulheres", "mais_mulheres"]]
# Out:
# Brasil — domicílios sem cônjuge e com filhos (Censo 2022)
#   mulheres: 10,321,771  (86.5%)
#   homens:   1,614,739  (13.5%)
#   6.4 mulheres para cada homem responsável
#
# Em todas as UFs/regiões mulheres > homens? True
#                  regiao   homens  mulheres  mais_mulheres
# 0                Brasil  1614739  10321771           True
# 1                 Norte   149246    759966           True
# 2              Nordeste   411968   3075080           True
# 3               Sudeste   700511   4405163           True
# 4                   Sul   228801   1308668           True
# 5          Centro-Oeste   124213    772894           True
# 6              Rondônia    12520     66077           True
# 7                  Acre     7166     40340           True
# 8              Amazonas    37693    167343           True
# 9               Roraima     5072     26618           True
# 10                 Pará    67853    355456           True
# 11                Amapá     7288     35670           True
# 12            Tocantins    11654     68462           True
# 13             Maranhão    50219    334269           True
# 14                Piauí    23505    168920           True
# 15                Ceará    64440    494429           True
# 16  Rio Grande do Norte    24132    180433           True
# 17              Paraíba    27585    213264           True
# 18           Pernambuco    64573    534210           True
# 19              Alagoas    21961    170745           True
# 20              Sergipe    16312    139668           True
# 21                Bahia   119241    839142           True
# 22         Minas Gerais   171679   1086509           True
# 23       Espírito Santo    30152    184412           True
# 24       Rio de Janeiro   146596    920698           True
# 25            São Paulo   352084   2213544           True
# 26               Paraná    85773    507637           True
# 27       Santa Catarina    53269    286888           True
# 28    Rio Grande do Sul    89759    514143           True
# 29   Mato Grosso do Sul    21034    129340           True
# 30          Mato Grosso    26431    146373           True
# 31                Goiás    52638    336370           True
# 32     Distrito Federal    24110    160811           True

# %% [markdown]
# ## Gráficos com matplotlib e seaborn
#
# Visualizamos o recorte **domicílios sem cônjuge e com filhos** e as **horas de afazeres** da Tabela 1.1.1.

# %%
regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]
ufs = indicador1e2[~indicador1e2["regiao"].isin(["Brasil"] + regioes)].copy()

# Barras: % de domicílios com responsável mulher
fig, ax = plt.subplots(figsize=(9, 8))
ordem = ufs.sort_values("pct_resp_mulheres", ascending=False)
sns.barplot(data=ordem, y="regiao", x="pct_resp_mulheres", ax=ax, color="teal")
ax.set_title("% de domicílios com responsável mulher (sem cônjuge + filhos)")
ax.set_xlabel("% com responsável mulher")
ax.set_ylabel("UF")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 2
#       1 regioes = ["Norte", "Nordeste", "Sudeste", "Sul", "Centro-Oeste"]
# ----> 2 ufs = indicador1e2[~indicador1e2["regiao"].isin(["Brasil"] + regioes)].copy()
#       3
#       4 # Barras: % de domicílios com responsável mulher
#       5 fig, ax = plt.subplots(figsize=(9, 8))
#
# NameError: name 'indicador1e2' is not defined

# %%
# Barras agrupadas: responsáveis homens x mulheres por grande região
reg = indicador_2[indicador_2["regiao"].isin(regioes)].copy()
reg_long = reg.melt(
    id_vars="regiao",
    value_vars=["homens", "mulheres"],
    var_name="sexo",
    value_name="domicilios",
)

fig, ax = plt.subplots(figsize=(9, 5))
sns.barplot(data=reg_long, x="regiao", y="domicilios", hue="sexo", ax=ax)
ax.set_title("Domicílios sem cônjuge e com filhos, por região e sexo do responsável")
ax.set_xlabel("Região")
ax.set_ylabel("Número de domicílios")
plt.tight_layout()
plt.show()

# %%
# Histograma (frequência) e box plot das horas das mulheres
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
sns.histplot(ufs["horas_mulher"], bins=8, kde=True, ax=axes[0])
axes[0].set_title("Frequência das horas médias das mulheres (UFs)")
axes[0].set_xlabel("Horas / semana")
axes[0].set_ylabel("Número de UFs")

sns.boxplot(y=ufs["horas_mulher"], ax=axes[1])
axes[1].set_title("Box plot das horas das mulheres por UF")
axes[1].set_ylabel("Horas / semana")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Histograma (frequência) e box plot das horas das mulheres
#       2 fig, axes = plt.subplots(1, 2, figsize=(12, 4))
# ----> 3 sns.histplot(ufs["horas_mulher"], bins=8, kde=True, ax=axes[0])
#       4 axes[0].set_title("Frequência das horas médias das mulheres (UFs)")
#       5 axes[0].set_xlabel("Horas / semana")
#       6 axes[0].set_ylabel("Número de UFs")
#
# NameError: name 'ufs' is not defined

# %%
# Box plot: % de responsáveis mulheres por UF
fig, ax = plt.subplots(figsize=(5, 4))
sns.boxplot(y=ufs["pct_resp_mulheres"], ax=ax, color="teal")
ax.set_title("Box plot: % responsável mulher nas UFs")
ax.set_ylabel("%")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Box plot: % de responsáveis mulheres por UF
#       2 fig, ax = plt.subplots(figsize=(5, 4))
# ----> 3 sns.boxplot(y=ufs["pct_resp_mulheres"], ax=ax, color="teal")
#       4 ax.set_title("Box plot: % responsável mulher nas UFs")
#       5 ax.set_ylabel("%")
#       6 plt.tight_layout()
#
# NameError: name 'ufs' is not defined

# %%
# Dispersão: será que mais responsáveis mulheres anda junto com mais horas em casa?
fig, ax = plt.subplots(figsize=(8, 5))
sns.scatterplot(data=ufs, x="pct_resp_mulheres", y="horas_mulher", ax=ax, s=80)
for _, row in ufs.iterrows():
    ax.annotate(row["regiao"], (row["pct_resp_mulheres"], row["horas_mulher"]), fontsize=7)
ax.set_title("Responsável mulher (%) × horas de afazeres das mulheres")
ax.set_xlabel("% domicílios com responsável mulher")
ax.set_ylabel("Horas / semana (mulheres)")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 3
#       1 # Dispersão: será que mais responsáveis mulheres anda junto com mais horas em casa?
#       2 fig, ax = plt.subplots(figsize=(8, 5))
# ----> 3 sns.scatterplot(data=ufs, x="pct_resp_mulheres", y="horas_mulher", ax=ax, s=80)
#       4 for _, row in ufs.iterrows():
#       5     ax.annotate(row["regiao"], (row["pct_resp_mulheres"], row["horas_mulher"]), fontsize=7)
#       6 ax.set_title("Responsável mulher (%) × horas de afazeres das mulheres")
#
# NameError: name 'ufs' is not defined

# %%
# Frequência: neste recorte, mulheres são maioria entre os responsáveis?
ufs["maioria"] = "Mais mulheres"
ufs.loc[ufs["resp_domicilio_mulheres"] <= ufs["resp_domicilio_homens"], "maioria"] = "Mais homens"

fig, ax = plt.subplots(figsize=(6, 4))
sns.countplot(data=ufs, x="maioria", ax=ax)
ax.set_title("Frequência de UFs segundo o sexo da maioria dos responsáveis")
ax.set_xlabel("")
ax.set_ylabel("Número de UFs")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 # Frequência: neste recorte, mulheres são maioria entre os responsáveis?
# ----> 2 ufs["maioria"] = "Mais mulheres"
#       3 ufs.loc[ufs["resp_domicilio_mulheres"] <= ufs["resp_domicilio_homens"], "maioria"] = "Mais homens"
#       4
#       5 fig, ax = plt.subplots(figsize=(6, 4))
#
# NameError: name 'ufs' is not defined
