# %%
import pandas as pd
import openpyxl

# %%
path = r"H:\Python\Etapa 3º\Aula 4\CD2022_Populacao_2010_Compatibilizada_20231222.xlsx"

# %%
table = pd.read_excel(path, header=None)

# %%
table
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 table
#
# NameError: name 'table' is not defined

# %%
table = table.iloc[3:5573,1].copy()

# %%
populacao_total.columns - ['UF', "cod_uf", "codmunic, "municipio, "pop_2010_sinopse', "pop_2010', 'pop_2022'] populacao_totall pop_2010 ] - pd.to_numeric(populacao_total[ pop_2010 ]) populacao_total[ pop_2022 ] - pd.to_numericpopulacao_total[' pop_2022 ])

# %%
popuLacao_total.head()
populacao_estado - populacao_total.groupby("UF')[[ pop_2010', pop_2022 ]]. sum(). reset_index() populacao_estado[ crescimento"] - populacao_estado[ pop_2022 ] - populacao_estado[ pop_2010°] populacao_estado - populacao_estado.sort_values(by-' crescimento', ascending-False)
print (populacao_estado)
populacao_estado.to_csv(" populacao_estado_crescimento.csv', index-False, sep-';', encoding-'utf-8-sig')
populacao_municipio - populacao_total[[ 'UF*, "municipio', "pop_2010°, 'pop_2022 1].copy() populacao_municipio[" crescimento"] - populacao_municipiolpop_2022 ] - populacao_municipiol"pop_2010'] populacao_municipio - populacao_municipio.sort_values(by-"crescimento', ascending-False)
print(populacao_municipio.head(15))
populacao_municipio.to_csv(' populacao_municipio_crescimento.csv', index-False, sep-':, encoding-'utf-8-s1g')
